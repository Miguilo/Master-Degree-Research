# %%
import pandas as pd
import datasist as ds
import numpy as np
# Out:
# /home/miguel/.cache/pypoetry/virtualenvs/apolar-molecules-R_6ouwk2-py3.9/lib/python3.9/site-packages/datasist/structdata.py:81: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(date_cols) is not 0:

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
# %ls
# Out:
# 14_moléculas.ipynb  apolar_molecules.ipynb  data_viz.ipynb

# %%
df_apol = pd.read_csv("../../data/raw/expd_apolar_molecules.CSV")
df_apol.head()
# Out:
#   Molecule Formula       Molecule Type  N of Carbon    Ei  Alpha  Expt    DYS
# 0   Butane   C4H10  Alkane and related          4.0  10.6    8.1    35   31.0  \
# 1  Pentane   C5H12  Alkane and related          5.0  10.4   10.0    60   54.0
# 2   Hexane   C6H14  Alkane and related          6.0  10.2   11.8    80   77.0
# 3  Heptane   C7H16  Alkane and related          7.0   9.9   13.7   105  100.0
# 4   Octane   C8H18  Alkane and related          8.0  10.0   15.5   115  123.0
#
#       SG  PauloPred     axx     ayy     azz     AlphaB  pi_bond
# 0   26.0       39.0   9.308   7.677   7.245   8.076667        0
# 1   56.0       54.0  11.725   9.393   8.743   9.953667        0
# 2   87.0       75.0  14.325  10.994  10.232  11.850333        0
# 3  117.0      105.0  16.910  12.658  11.715  13.761000        0
# 4  144.0      119.0  19.595  14.255  13.193  15.681000        0

# %%
df_apol = df_apol.drop(['Molecule Type', 'N of Carbon', 'DYS', 'SG', 'PauloPred'], axis=1)
df_apol
# Out:
#                       Molecule  Formula    Ei  Alpha  Expt     axx     ayy
# 0                       Butane    C4H10  10.6   8.10    35   9.308   7.677  \
# 1                      Pentane    C5H12  10.4  10.00    60  11.725   9.393
# 2                       Hexane    C6H14  10.2  11.80    80  14.325  10.994
# 3                      Heptane    C7H16   9.9  13.70   105  16.910  12.658
# 4                       Octane    C8H18  10.0  15.50   115  19.595  14.255
# 5                       Nonane    C9H20  10.0  17.40   145  21.310  14.930
# 6                     Dodecane   C12H26   9.9  22.90   220     NaN     NaN
# 7                   Hexadecane   C16H34   9.9  30.30   310     NaN     NaN
# 8                     Ethylene     C2H4  10.5   4.20    20   5.429   3.766
# 9                 Cyclopropane     C3H6   9.9   5.70    10   5.750   5.750
# 10                 Cyclohexane    C6H12   9.9  11.80    80  11.290  11.290
# ...

# %%
ds.structdata.describe(df_apol)
# Out:
# First five data points
#   Molecule Formula    Ei  Alpha  Expt     axx     ayy     azz     AlphaB
# 0   Butane   C4H10  10.6    8.1    35   9.308   7.677   7.245   8.076667  \
# 1  Pentane   C5H12  10.4   10.0    60  11.725   9.393   8.743   9.953667
# 2   Hexane   C6H14  10.2   11.8    80  14.325  10.994  10.232  11.850333
# 3  Heptane   C7H16   9.9   13.7   105  16.910  12.658  11.715  13.761000
# 4   Octane   C8H18  10.0   15.5   115  19.595  14.255  13.193  15.681000
#
#    pi_bond
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# Random five data points
#                       Molecule  Formula    Ei  Alpha  Expt     axx     ayy
# 8                     Ethylene     C2H4  10.5   4.20    20   5.429   3.766  \
# 13             2-3-butanedione   C4H6O2   9.3   8.20    77   9.758   9.073
# 18  1-2-trans-Dichloroethylene  C2H2Cl2   9.6   8.15    15  12.534   6.722
# 12                 Naphthalene    C10H8   8.2  16.60   300  25.712  18.700
# ...

# %%
df_apol = ds.feature_engineering.drop_missing(df_apol, percent = 10)
# Out:
# Dropped ['axx', 'ayy', 'azz', 'AlphaB']

# %%
df_apol.head()
# Out:
#   Molecule Formula    Ei  Alpha  Expt  pi_bond
# 0   Butane   C4H10  10.6    8.1    35        0
# 1  Pentane   C5H12  10.4   10.0    60        0
# 2   Hexane   C6H14  10.2   11.8    80        0
# 3  Heptane   C7H16   9.9   13.7   105        0
# 4   Octane   C8H18  10.0   15.5   115        0

# %%
ds.visualizations.scatterplot(df_apol, target='Expt', separate_by='pi_bond',)
