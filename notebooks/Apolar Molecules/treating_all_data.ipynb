# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_percentage_error

# %%
df = pd.read_csv("../../data/final/all_info.csv")
df.head(20)
# Out:
#                       Molecule  Formula    Ei  Alpha   axx   ayy   azz  \
# 0                       Butane    C4H10  10.6    8.1   9.3   7.7   7.2
# 1                      Pentane    C5H12  10.4   10.0  11.7   9.4   8.7
# 2                       Hexane    C6H14  10.2   11.8  14.3  11.0  10.2
# 3                      Heptane    C7H16   9.9   13.7  16.9  12.7  11.7
# 4                       Octane    C8H18  10.0   15.5  19.6  14.3  13.2
# 5                       Nonane    C9H20  10.0   17.4  21.3  14.9  14.0
# 6                     Dodecane   C12H26   9.9   22.9   NaN   NaN   NaN
# 7                   Hexadecane   C16H34   9.9   30.3   NaN   NaN   NaN
# 8                     Ethylene     C2H4  10.5    4.2   5.4   3.8   3.3
# 9                 Cyclopropane     C3H6   9.9    5.7   5.8   5.8   5.0
# 10                 Cyclohexane    C6H12   9.9   11.8  11.3  11.3   9.8
# 11                     Benzene     C6H6   9.3   10.4  12.3  12.3   6.7
# ...

# %%
df[["Expt", "DYS_A", "DYS_B"]] = np.int32(np.round(df[["Expt", "DYS_A", "DYS_B"]]))

# %%
df.head(20)
# Out:
#                       Molecule  Formula    Ei  Alpha   axx   ayy   azz  \
# 0                       Butane    C4H10  10.6    8.1   9.3   7.7   7.2
# 1                      Pentane    C5H12  10.4   10.0  11.7   9.4   8.7
# 2                       Hexane    C6H14  10.2   11.8  14.3  11.0  10.2
# 3                      Heptane    C7H16   9.9   13.7  16.9  12.7  11.7
# 4                       Octane    C8H18  10.0   15.5  19.6  14.3  13.2
# 5                       Nonane    C9H20  10.0   17.4  21.3  14.9  14.0
# 6                     Dodecane   C12H26   9.9   22.9   NaN   NaN   NaN
# 7                   Hexadecane   C16H34   9.9   30.3   NaN   NaN   NaN
# 8                     Ethylene     C2H4  10.5    4.2   5.4   3.8   3.3
# 9                 Cyclopropane     C3H6   9.9    5.7   5.8   5.8   5.0
# 10                 Cyclohexane    C6H12   9.9   11.8  11.3  11.3   9.8
# 11                     Benzene     C6H6   9.3   10.4  12.3  12.3   6.7
# ...

# %%
df.to_csv("../../data/final/all_info.csv", index=False)

# %%
df_apol = df.query("Dipole == 0")
df_apol
# Out:
#                       Molecule  Formula    Ei  Alpha   axx   ayy   azz  \
# 0                       Butane    C4H10  10.6    8.1   9.3   7.7   7.2
# 1                      Pentane    C5H12  10.4   10.0  11.7   9.4   8.7
# 2                       Hexane    C6H14  10.2   11.8  14.3  11.0  10.2
# 3                      Heptane    C7H16   9.9   13.7  16.9  12.7  11.7
# 4                       Octane    C8H18  10.0   15.5  19.6  14.3  13.2
# 5                       Nonane    C9H20  10.0   17.4  21.3  14.9  14.0
# 6                     Dodecane   C12H26   9.9   22.9   NaN   NaN   NaN
# 7                   Hexadecane   C16H34   9.9   30.3   NaN   NaN   NaN
# 8                     Ethylene     C2H4  10.5    4.2   5.4   3.8   3.3
# 9                 Cyclopropane     C3H6   9.9    5.7   5.8   5.8   5.0
# 10                 Cyclohexane    C6H12   9.9   11.8  11.3  11.3   9.8
# 11                     Benzene     C6H6   9.3   10.4  12.3  12.3   6.7
# ...

# %%
np.round(df_apol.describe(),2)
# Out:
#           Ei  Alpha    axx    ayy    azz  AlphaB  pi_bond  Dipole    Expt  \
# count  20.00  20.00  17.00  17.00  17.00   17.00    20.00    20.0   20.00
# mean    9.92  12.93  13.09  10.16   8.17   10.49     0.75     0.0  109.20
# std     0.60   6.93   5.46   4.03   3.01    3.92     1.33     0.0   94.10
# min     8.20   4.20   5.40   3.80   3.30    4.20     0.00     0.0   10.00
# 25%     9.82   8.20   9.80   6.70   5.70    8.10     0.00     0.0   51.50
# 50%     9.90  11.10  12.30   9.90   7.80   10.00     0.00     0.0   78.50
# 75%    10.22  15.78  15.10  12.70   9.80   12.30     1.00     0.0  146.25
# max    11.10  30.30  25.70  18.70  14.00   18.10     5.00     0.0  310.00
#
#         DYS_A   DYS_B
# count   20.00   20.00
# mean   102.85  113.30
# std     96.08   90.14
# min    -17.00    1.00
# 25%     32.00   55.00
# 50%     77.00   95.00
# 75%    146.75  146.75
# max    306.00  306.00
